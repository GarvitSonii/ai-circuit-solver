# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\garvi\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 2.2MB/s 2.9s.8s<0.1s3.1s9s

# %%
image_path = "test_image_1.jpg"
img = cv2.imread(image_path)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
results = model(img_rgb)
# Out:
# 0: 384x640 2 cars, 2 buss, 5 trucks, 192.1ms
# Speed: 34.3ms preprocess, 192.1ms inference, 22.2ms postprocess per image at shape (1, 3, 384, 640)

# %%
results[0].show()

# %%
plt.imshow(results[0].plot())
plt.axis("off")
plt.show()

# %%
for r in results:
    for box in r.boxes:
        cls_id = int(box.cls[0])
        label = model.names[cls_id]
        conf = float(box.conf[0])
        print(f"Detected {label} with {conf:.2f} confidence")
# Out:
# Detected car with 0.81 confidence
# Detected truck with 0.77 confidence
# Detected bus with 0.72 confidence
# Detected bus with 0.72 confidence
# Detected truck with 0.54 confidence
# Detected truck with 0.39 confidence
# Detected car with 0.38 confidence
# Detected truck with 0.38 confidence
# Detected truck with 0.28 confidence
